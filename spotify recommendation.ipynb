# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
df=pd.read_csv('spotify.csv')

# %%
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (174389, 19)

# %%
df.drop(['id','name','artists','release_date','year'],axis=1)
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 0           0.991000         0.598       168333   0.224         0
# 1           0.643000         0.852       150200   0.517         0
# 2           0.993000         0.647       163827   0.186         0
# 3           0.000173         0.730       422087   0.798         0
# 4           0.295000         0.704       165224   0.707         1
# ...              ...           ...          ...     ...       ...
# 174384      0.009170         0.792       147615   0.866         0
# 174385      0.795000         0.429       144720   0.211         0
# 174386      0.806000         0.671       218147   0.589         0
# 174387      0.920000         0.462       244000   0.240         1
# 174388      0.239000         0.677       197710   0.460         0
#
#         instrumentalness  key  liveness  loudness  mode  popularity  \
# 0               0.000522    5    0.3790   -12.628     0          12
# ...

# %%
df.tail()
# Out:
#         acousticness                             artists  danceability  \
# 174384       0.00917  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385       0.79500                    ['Alessia Cara']         0.429
# 174386       0.80600                       ['Roger Fly']         0.671
# 174387       0.92000                    ['Taylor Swift']         0.462
# 174388       0.23900                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# 174384       147615   0.866         0  46LhBf6TvYjZU2SMvGZAbn
# 174385       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
# 174386       218147   0.589         0  48Qj61hOdYmUCFJbpQ29Ob
# 174387       244000   0.240         1  1gcyHQpBQ1lfXGdhZmWrHP
# 174388       197710   0.460         0  57tgYkWQTNHVFEt6xDKKZj
#
#         instrumentalness  key  liveness  loudness  mode                name  \
# 174384           0.00006    6     0.178    -5.089     0             The One
# ...

# %%
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.263217    -0.089169 -0.750852 -0.208176
# danceability         -0.263217      1.000000    -0.100757  0.204838  0.200842
# duration_ms          -0.089169     -0.100757     1.000000  0.060516 -0.033808
# energy               -0.750852      0.204838     0.060516  1.000000  0.102561
# explicit             -0.208176      0.200842    -0.033808  0.102561  1.000000
# instrumentalness      0.221956     -0.215589     0.103621 -0.177750 -0.130609
# key                  -0.028028      0.026266     0.002020  0.035780  0.005282
# liveness             -0.029654     -0.110033     0.028942  0.134815  0.037288
# loudness             -0.546639      0.249541     0.019791  0.779267  0.106249
# mode                  0.064633     -0.048358    -0.046849 -0.056160 -0.062503
# popularity           -0.396744      0.123746     0.024717  0.328939  0.152545
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='cool')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
datatypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
scalers = {}
normarization = df.select_dtypes(include=datatypes)
for col in normarization.columns:
    scalers[col] = MinMaxScaler(col)

# %%
scalers
# Out:
# {'acousticness': MinMaxScaler(feature_range='acousticness'),
#  'danceability': MinMaxScaler(feature_range='danceability'),
#  'duration_ms': MinMaxScaler(feature_range='duration_ms'),
#  'energy': MinMaxScaler(feature_range='energy'),
#  'explicit': MinMaxScaler(feature_range='explicit'),
#  'instrumentalness': MinMaxScaler(feature_range='instrumentalness'),
#  'key': MinMaxScaler(feature_range='key'),
#  'liveness': MinMaxScaler(feature_range='liveness'),
#  'loudness': MinMaxScaler(feature_range='loudness'),
#  'mode': MinMaxScaler(feature_range='mode'),
#  'popularity': MinMaxScaler(feature_range='popularity'),
#  'speechiness': MinMaxScaler(feature_range='speechiness'),
#  'tempo': MinMaxScaler(feature_range='tempo'),
#  'valence': MinMaxScaler(feature_range='valence'),
#  'year': MinMaxScaler(feature_range='year')}

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=10)
features = kmeans.fit_predict(normarization)

# %%
df['features'] = features
MinMaxScaler(df['features'])
# Out:
# MinMaxScaler(feature_range=0         1
# 1         1
# 2         1
# 3         7
# 4         1
#          ..
# 174384    1
# 174385    1
# 174386    6
# 174387    6
# 174388    1
# Name: features, Length: 174389, dtype: int32)

# %%
df.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
df.to_csv('spotify clusters.csv', index=False)

# %%
pd.read_csv('spotify clusters.csv')
# Out:
#         acousticness                             artists  danceability  \
# 0           0.991000                     ['Mamie Smith']         0.598
# 1           0.643000           ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                     ['Mamie Smith']         0.647
# 3           0.000173                 ['Oscar Velazquez']         0.730
# 4           0.295000                            ['Mixe']         0.704
# ...              ...                                 ...           ...
# 174384      0.009170  ['DJ Combo', 'Sander-7', 'Tony T']         0.792
# 174385      0.795000                    ['Alessia Cara']         0.429
# 174386      0.806000                       ['Roger Fly']         0.671
# 174387      0.920000                    ['Taylor Swift']         0.462
# 174388      0.239000                       ['Roger Fly']         0.677
#
#         duration_ms  energy  explicit                      id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %%
class Spotify_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(songs[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

recommendations = Spotify_Recommendation(df)
recs = recommendations.recommend("Lovers Rock", 10)
# Out:
# 100%|██████████| 174387/174387 [00:20<00:00, 8336.45it/s]
# /var/folders/4y/pcdt74h51_x2zz4w3hlpvzxh0000gn/T/ipykernel_38808/487027359.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance

# %%
import pickle

# %%
pickle.dump(scalers, open('Scalers.pkl','wb'))

# %%
recs
# Out:
#                                artists                       name
# 103171              ['Barão Vermelho']               Bete Balanço
# 55318                    ['Shinedown']                    Save Me
# 16385                       ['O-Zone']          Dragostea Din Tei
# 11168     ['Bob Marley & The Wailers']         Positive Vibration
# 158441              ["Olivia O'Brien"]                Love Myself
# 54226   ['Naughty By Nature', 'Zhané']     Jamboree (feat. Zhané)
# 85047                  ['The Outlaws']               Song For You
# 50644     ['The Alan Parsons Project']  Mammagamma - Instrumental
# 107163              ['Britney Spears']             My Prerogative
# 35098                    ['Los Askis']               ¡Ay! El Amor

# %%
for artists, songs in recs.values:
    print(songs, "by", artists[1:-1].replace("'", "").replace('"', ""))
# Out:
# Bete Balanço by Barão Vermelho
# Save Me by Shinedown
# Dragostea Din Tei by O-Zone
# Positive Vibration by Bob Marley & The Wailers
# Love Myself by Olivia OBrien
# Jamboree (feat. Zhané) by Naughty By Nature, Zhané
# Song For You by The Outlaws
# Mammagamma - Instrumental by The Alan Parsons Project
# My Prerogative by Britney Spears
# ¡Ay! El Amor by Los Askis

# %%
str1 = str(["Olivia O'Brien"])

# %%
str1
# Out:
# '["Olivia O\'Brien"]'

# %%
str1[1:-1].replace('"', "").
# Out:
# "Olivia O'Brien"
